# %% [markdown]
# # ALGORITHM
#
# 1. import requests, json, googleplaces
# 2. define functions for sentment analysis(user mood) and geocode(location)
# 3. define variables for url, options, response, sentiment, geodata, sent_res, coords
# 4. return sent_res, coords
# 5. insert api key
# 6. input mood
# 7. use boolean statements to determine users mood based on input
# 8. input location
# 9. call geocoding function
# 10. input activity
# 11. use for loop for print statements
# 12. use try except to handle errors

# %%
import requests
import json 
from googleplaces import GooglePlaces, types, lang

def sentminent_analysis(user_mood):
    url = 'http://text-processing.com/api/sentiment/'
    options = { 'text' : user_mood }
    response = requests.post(url, data = options)
    sentiment = response.json()
    sent_res = sentiment['label']
    return sent_res

def geocode(location):
    url = 'http://maps.googleapis.com/maps/api/geocode/json'

    options = { 'address' : location }  
    response = requests.get(url, params = options)            
    geodata = response.json()
    coords = geodata['results'][0]['geometry']['location']
    return coords

apikey='AIzaSyAMyphnOcHYBpDzXi3TekIEqjf6IMLMCoU'
try:
    user_mood = input('How are you feeling today? ')
    mood_prompt = ''

    sent_ana = sentminent_analysis(user_mood)

    if sent_ana == 'pos':
        print('Yay, you are in a good mood. Lets find an activity that will keep you in a good mood. ')

    elif sent_ana == 'neg':
        print("That's not good. You're in a bad mood. Lets find an activity that will get you in a better mood. ")

    elif sent_ana == 'neutral':
        print('Your sentiments seem to be neutral to me. Lets find an activity that will get you in a better mood .')

    google_places = GooglePlaces(apikey)

    location = input('What city and state are you currently located in? (ex: Syracuse, NY) ')
    latlng = geocode(location)



    activity = input('Enter an activity to search: ')
    print('\n')
    print('Below are establishments for the activity that you entered. Hopefully these will stimulate your mood:')
    print('\n')
    query_result = google_places.text_search(query=activity, language='en', lat_lng= latlng, radius=3200, type=None, types=[], location=None, pagetoken=None)

    if query_result.has_attributions:
        print (query_result.html_attributions)


    for place in query_result.places:
        place.get_details()
        print (place.name)
        print ('Rating of %s out of 5' % place.rating)
        print ('The address of the establishment is: %s' % place.formatted_address)
        print ('Phone Number: %s' % place.local_phone_number)
        print ('International Phone Number: %s' % place.international_phone_number)
        print ('Website of establishment: %s' % place.website)
        print ('Google Places place url: %s' % place.url)
        print ('\n')
        
except IndexError as e:
    print('Oops, something went wrong.', e, 'Please ensure that you enter an accurate location')
    
except json.decoder.JSONDecodeError as e: 
    print("ERROR: Cannot decode the response into json")
    print("DETAILS", e)

except requests.exceptions.HTTPError as e:
    print("ERROR: Response from ", url, 'was not ok.')
    print("DETAILS:", e)
        
except requests.exceptions.RequestException as e: 
    
    print("ERROR: Cannot connect to ", url)
    

    print("DETAILS:", e)
# Out:
# How are you feeling today? great
# Yay, you are in a good mood. Lets find an activity that will keep you in a good mood.
# What city and state are you currently located in? (ex: Syracuse, NY) syracuse ny
# Enter an activity to search: ice skating
#
#
# Below are establishments for the activity that you entered. Hopefully these will stimulate your mood:
#
#
# Clinton Square Ice Rink
# Rating of 4.2 out of 5
# The address of the establishment is: 2 S Clinton St, Syracuse, NY 13202, USA
# Phone Number: (315) 423-0129
# International Phone Number: +1 315-423-0129
# Website of establishment: http://www.syracuse.ny.us/Parks/clintonSquareEvents.html
# Google Places place url: https://maps.google.com/?cid=267382742246685592
#
#
# Sunnycrest Arena
# Rating of 3.8 out of 5
# The address of the establishment is: 699 Robinson St, Syracuse, NY 13206, USA
# Phone Number: (315) 473-4696
# International Phone Number: +1 315-473-4696
# Website of establishment: http://www.syracuse.ny.us/parks/sunnycrestrink.html
# Google Places place url: https://maps.google.com/?cid=1752050693066825945
#
#
# Tennity Ice Pavilion
# Rating of 4.7 out of 5
# The address of the establishment is: 511 Skytop Rd, Syracuse, NY 13244, USA
# Phone Number: (315) 443-4254
# International Phone Number: +1 315-443-4254
# Website of establishment: http://skate.syr.edu/
# Google Places place url: https://maps.google.com/?cid=5378459122916252327
#
#
# Meachem Ice Rink
# Rating of 4.6 out of 5
# The address of the establishment is: 121 W Seneca Turnpike, Syracuse, NY 13205, USA
# Phone Number: (315) 492-0179
# International Phone Number: +1 315-492-0179
# Website of establishment: http://www.syracuse.ny.us/Parks/MeachemIceRink.html
# Google Places place url: https://maps.google.com/?cid=14806843651779941391
#
#
# Onondaga Nation Arena
# Rating of 4.5 out of 5
# The address of the establishment is: 326 US-11, Nedrow, NY 13120, USA
# Phone Number: (315) 498-6813
# International Phone Number: +1 315-498-6813
# Website of establishment: http://onondagaarena.com/
# Google Places place url: https://maps.google.com/?cid=15399438403929070951
#
#
# Allyn Ice Arena
# Rating of 4.6 out of 5
# The address of the establishment is: 97 State St, Skaneateles, NY 13152, USA
# Phone Number: (315) 685-2266
# International Phone Number: +1 315-685-2266
# Website of establishment: https://auburnymca.org/skaneateles/ice/
# Google Places place url: https://maps.google.com/?cid=2088778730786425908
#
#
# Rockefeller Center Ice Skating Rink
# Rating of 4.9 out of 5
# The address of the establishment is: 5th Ave, New York, NY 10112, USA
# Phone Number: (212) 588-8601
# International Phone Number: +1 212-588-8601
# Website of establishment: https://therinkatrockcenter.com/
# Google Places place url: https://maps.google.com/?cid=2419803240029949842
#
#
# Reston Ice Skating
# Rating of 4.5 out of 5
# The address of the establishment is: 1818 Discovery St, Reston, VA 20190, USA
# Phone Number: (703) 709-6300
# International Phone Number: +1 703-709-6300
# Website of establishment: https://www.restontowncenter.com/amenities/ice-skating/
# Google Places place url: https://maps.google.com/?cid=2062749797842736184
#
#
# Town of Oyster Bay Ice Skating Center
# Rating of 4.4 out of 5
# The address of the establishment is: 1001 Stewart Ave, Bethpage, NY 11714, USA
# Phone Number: (516) 433-7465
# International Phone Number: +1 516-433-7465
# Website of establishment: http://oysterbaytown.com/departments/parks/ice-skating/ice-skating-center-at-bethpage/
# Google Places place url: https://maps.google.com/?cid=11007114986635948781
#
#
# Galleria Ice Skating Center
# Rating of 3.6 out of 5
# The address of the establishment is: 13350 Dallas Pkwy #200, Dallas, TX 75240, USA
# Phone Number: (972) 392-3363
# International Phone Number: +1 972-392-3363
# Website of establishment: http://www.galleriaiceskatingcenter.com/
# Google Places place url: https://maps.google.com/?cid=15456527572883542317
#
#
# Riverbank State Park Ice Skating Rink
# Rating of 4.2 out of 5
# The address of the establishment is: 679 Riverside Dr, New York, NY 10031, USA
# Phone Number: (212) 694-3642
# International Phone Number: +1 212-694-3642
# Website of establishment: https://parks.ny.gov/parks/93
# Google Places place url: https://maps.google.com/?cid=9709598155695729502
#
#
# Fritz Dietl Ice Skating Rink
# Rating of 3.2 out of 5
# The address of the establishment is: 639 Broadway, Westwood, NJ 07675, USA
# Phone Number: (201) 664-9812
# International Phone Number: +1 201-664-9812
# Website of establishment: http://www.fritzdietlicerink.com/
# Google Places place url: https://maps.google.com/?cid=5163830487111358771
#
#
# Wintersport Ice Sports Arena
# Rating of 4.3 out of 5
# The address of the establishment is: 551 York Rd, Willow Grove, PA 19090, USA
# Phone Number: (215) 659-4253
# International Phone Number: +1 215-659-4253
# Website of establishment: http://wintersportsice.com/
# Google Places place url: https://maps.google.com/?cid=7429451726174586994
#
#
# WW II Ice Skating Rink
# Rating of 3.3 out of 5
# The address of the establishment is: 1305-, 1321 Victory Blvd, Staten Island, NY 10301, USA
# Phone Number: (718) 720-1010
# International Phone Number: +1 718-720-1010
# Website of establishment: https://www.nycgovparks.org/facilities/iceskating/6
# Google Places place url: https://maps.google.com/?cid=3135063024002766949
#
#
# Ice Skating Rink Wissahickon
# Rating of 4.3 out of 5
# The address of the establishment is: 550 W Willow Grove Ave, Philadelphia, PA 19118, USA
# Phone Number: (215) 247-1759
# International Phone Number: +1 215-247-1759
# Website of establishment: http://www.wissskating.com/
# Google Places place url: https://maps.google.com/?cid=15539020141691724275
#
#
# Springfield Ice Skating Rink
# Rating of 4.2 out of 5
# The address of the establishment is: 400 W Sproul Rd, Springfield, PA 19064, USA
# Phone Number: (610) 544-6670
# International Phone Number: +1 610-544-6670
# Website of establishment: http://springfieldicerink.com/
# Google Places place url: https://maps.google.com/?cid=10705957094213076712
#
#
# Sunbury Ice Skating Rink and Community Center
# Rating of 4.7 out of 5
# The address of the establishment is: 1200 Memorial Dr, Sunbury, PA 17801, USA
# Phone Number: (570) 286-1441
# International Phone Number: +1 570-286-1441
# Website of establishment: http://www.cityofsunbury.com/Pages/Community/Parks%20and%20Recreation/IceSkatingRinkandCommunityCenter.aspx
# Google Places place url: https://maps.google.com/?cid=6143539117926926676
#
#
# South Park Ice Skating Rink
# Rating of 4.9 out of 5
# The address of the establishment is: 30 Corrigan Dr, Bethel Park, PA 15102, USA
# Phone Number: (412) 833-1499
# International Phone Number: +1 412-833-1499
# Website of establishment: http://www.alleghenycounty.us/parks/activities/winter-sports/ice-skating.aspx
# Google Places place url: https://maps.google.com/?cid=10745244748200551289
#
#
# National Gallery of Art Sculpture Garden Ice Rink
# Rating of 4.7 out of 5
# The address of the establishment is: Constitution Ave NW & 7th Street, Washington, DC 20408, USA
# Phone Number: (202) 216-9397
# International Phone Number: +1 202-216-9397
# Website of establishment: http://www.nga.gov/content/ngaweb/visit/ice-rink.html
# Google Places place url: https://maps.google.com/?cid=7543767034004224081
